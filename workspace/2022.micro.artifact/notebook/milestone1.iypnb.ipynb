# %%
# %%bash
# cd /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts
# echo "Running evaluation sweep for unstructured sparse architecture"
# chmod +x sweep1.sh
# time ./sweep1.sh
# Out:
# Running evaluation sweep for unstructured sparse architecture
# Processing resnet50_conv1 with unstructured_sparse_tensor_core...
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using all available hardware threads = 11
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 6
#   Factorization options along problem dimension M = 462
#   Factorization options along problem dimension R = 6
#   Factorization options along problem dimension S = 6
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 756
#   Factorization options along problem dimension Q = 756
# Mapspace Dimension [IndexFactorization] Size: 57034720512
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 64
# Mapspace Dimension [DatatypeBypass] Size: 512
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 5184974592 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  7] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  9] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  0] Utilization = 0.00 | pJ/Compute =  128.229 | L3[WIO] Q1 - L2[] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  4] Utilization = 0.00 | pJ/Compute =  128.229 | L3[WIO] Q1 - L2[] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =   85.563 | L3[WIO] Q1 - L2[] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.20 | pJ/Compute =   45.372 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [ 10] Utilization = 0.20 | pJ/Compute =   45.372 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  2] Utilization = 0.00 | pJ/Compute =  128.229 | L3[WIO] Q1 - L2[] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.20 | pJ/Compute =   45.372 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  5] Utilization = 0.00 | pJ/Compute =  128.229 | L3[WIO] C3 - L2[] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =   14.957 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [ 10] Utilization = 0.22 | pJ/Compute =   13.456 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  2] Utilization = 0.00 | pJ/Compute =   97.814 | L3[WIO] Q1 - L2[] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  0] Utilization = 0.00 | pJ/Compute =   97.814 | L3[WIO] Q1 - L2[] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  8] Utilization = 0.22 | pJ/Compute =   13.456 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =   55.148 | L3[WIO] Q1 - L2[] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =   97.814 | L3[WIO] Q1 - L2[] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =   13.393 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.00 | pJ/Compute =   97.814 | L3[WIO] C3 - L2[] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =   13.390 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =   13.392 | L3[WIO] M2 - L2[W] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.00 | pJ/Compute =   70.051 | L3[WIO] Q1 - L2[I] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  2] Utilization = 0.00 | pJ/Compute =   70.051 | L3[WIO] Q1 - L2[I] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =   11.529 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  5] Utilization = 0.00 | pJ/Compute =   70.051 | L3[WIO] C3 - L2[I] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =   10.028 | L3[WIO] M2 - L2[I] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =   10.028 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  4] Utilization = 0.00 | pJ/Compute =   70.051 | L3[WIO] Q1 - L2[I] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =   27.384 | L3[WIO] Q1 - L2[I] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    9.963 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    9.966 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.00 | pJ/Compute =   43.127 | L3[WIO] Q1 - L2[O] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  0] Utilization = 0.00 | pJ/Compute =   15.364 | L3[WIO] Q1 - L2[IO] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    9.964 | L3[WIO] M2 - L2[WI] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  2] Utilization = 0.00 | pJ/Compute =   43.127 | L3[WIO] Q1 - L2[O] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    6.019 | L3[WIO] M2 - L2[O] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    5.954 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  2] Utilization = 0.00 | pJ/Compute =   15.364 | L3[WIO] Q1 - L2[IO] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =   43.127 | L3[WIO] Q1 - L2[O] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =    7.521 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  8] Utilization = 0.22 | pJ/Compute =    2.592 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  4] Utilization = 0.00 | pJ/Compute =   15.364 | L3[WIO] Q1 - L2[IO] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    2.526 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    9.448 | L3[WIO] Q1 - L2[IO] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =    4.093 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  5] Utilization = 0.00 | pJ/Compute =   43.127 | L3[WIO] C3 - L2[O] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    6.019 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    5.957 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.00 | pJ/Compute =   15.364 | L3[WIO] C3 - L2[IO] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    5.955 | L3[WIO] M2 - L2[WO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    2.592 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =   49.372 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    2.529 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =   18.957 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    2.528 | L3[WIO] M2 - L2[WIO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =   12.053 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  2] Utilization = 0.11 | pJ/Compute =   49.372 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =   18.957 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =   12.053 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =   49.372 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =   18.960 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =   11.521 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  4] Utilization = 0.11 | pJ/Compute =   18.958 | L3[WIO] M2 - L2[W] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =   49.372 | L3[WIO] M2 C3 - L2[] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =   11.521 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =   18.957 | L3[WIO] M2 C3 - L2[] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =   12.056 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =   12.054 | L3[WIO] M2 - L2[WI] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    4.617 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  2] Utilization = 0.11 | pJ/Compute =    4.617 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =   12.102 | L3[WIO] M2 C3 - L2[I] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =   11.523 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =   11.522 | L3[WIO] M2 - L2[WO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =    4.619 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =    4.618 | L3[WIO] M2 - L2[WIO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =   11.521 | L3[WIO] M2 C3 - L2[O] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    4.665 | L3[WIO] M2 C3 - L2[IO] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.19 | pJ/Compute =   43.277 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.33 | pJ/Compute =   12.862 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.33 | pJ/Compute =    5.958 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.33 | pJ/Compute =    3.771 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  8] STATEMENT: 91 valid mappings found, terminating search.
# [ 10] STATEMENT: 91 valid mappings found, terminating search.
# [  6] STATEMENT: 91 valid mappings found, terminating search.
# [  0] STATEMENT: 91 valid mappings found, terminating search.
# [  2] STATEMENT: 91 valid mappings found, terminating search.
# [  4] STATEMENT: 91 valid mappings found, terminating search.
# [  1] STATEMENT: 91 valid mappings found, terminating search.
# [  5] STATEMENT: 91 valid mappings found, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 0.33 | pJ/Compute =    3.771
# Processing alexnet_conv1_sparse with unstructured_sparse_tensor_core...
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using all available hardware threads = 11
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 6
#   Factorization options along problem dimension M = 1512
#   Factorization options along problem dimension R = 6
#   Factorization options along problem dimension S = 6
#   Factorization options along problem dimension N = 21
#   Factorization options along problem dimension P = 336
#   Factorization options along problem dimension Q = 336
# Mapspace Dimension [IndexFactorization] Size: 774289539072
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 64
# Mapspace Dimension [DatatypeBypass] Size: 512
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 70389958098 Residue: 6
# Mapspace construction complete.
# Search configuration complete.
# [  6] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  8] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [ 10] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  9] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 0.00 | pJ/Compute =  128.359 | L3[WIO] Q1 - L2[] Q1 - L1[] C3 - L0[] Q56 P56 N4 S11 R11 M96
# [  5] Utilization = 0.00 | pJ/Compute =  128.359 | L3[WIO] C3 - L2[] Q1 - L1[] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  4] Utilization = 0.00 | pJ/Compute =  128.359 | L3[WIO] Q1 - L2[] C3 - L1[] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  0] Utilization = 0.00 | pJ/Compute =  128.359 | L3[WIO] Q1 - L2[] Q1 - L1[] Q1 - L0[] Q56 P56 N4 S11 R11 M96 C3
# [  1] Utilization = 0.01 | pJ/Compute =   85.692 | L3[WIO] Q1 - L2[] Q1 - L1[] Q1 C3Y - L0[] Q56 P56 N4 S11 R11 M96
# [  1] Utilization = 0.01 | pJ/Compute =   57.883 | L3[WIO] Q1 - L2[W] Q1 - L1[] Q1 C3Y - L0[] Q56 P56 N4 S11 R11 M96
# [  2] Utilization = 0.00 | pJ/Compute =  100.550 | L3[WIO] Q1 - L2[W] Q1 - L1[] C3 - L0[] Q56 P56 N4 S11 R11 M96
# [  0] Utilization = 0.00 | pJ/Compute =  100.550 | L3[WIO] Q1 - L2[W] Q1 - L1[] Q1 - L0[] Q56 P56 N4 S11 R11 M96 C3
# [  5] Utilization = 0.00 | pJ/Compute =   97.944 | L3[WIO] C3 - L2[] Q1 - L1[W] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  4] Utilization = 0.00 | pJ/Compute =   97.944 | L3[WIO] Q1 - L2[] C3 - L1[W] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  1] Utilization = 0.01 | pJ/Compute =   30.125 | L3[WIO] Q1 - L2[WI] Q1 - L1[] Q1 C3Y - L0[] Q56 P56 N4 S11 R11 M96
# [  0] Utilization = 0.00 | pJ/Compute =   72.791 | L3[WIO] Q1 - L2[WI] Q1 - L1[] Q1 - L0[] Q56 P56 N4 S11 R11 M96 C3
# [  4] Utilization = 0.00 | pJ/Compute =   70.185 | L3[WIO] Q1 - L2[I] C3 - L1[W] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  5] Utilization = 0.00 | pJ/Compute =   70.185 | L3[WIO] C3 - L2[I] Q1 - L1[W] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  2] Utilization = 0.00 | pJ/Compute =   72.791 | L3[WIO] Q1 - L2[WI] Q1 - L1[] C3 - L0[] Q56 P56 N4 S11 R11 M96
# [  0] Utilization = 0.00 | pJ/Compute =   45.601 | L3[WIO] Q1 - L2[WO] Q1 - L1[] Q1 - L0[] Q56 P56 N4 S11 R11 M96 C3
# [  1] Utilization = 0.01 | pJ/Compute =   11.927 | L3[WIO] Q1 - L2[WIO] Q1 - L1[] Q1 C3Y - L0[] Q56 P56 N4 S11 R11 M96
# [  4] Utilization = 0.00 | pJ/Compute =   42.995 | L3[WIO] Q1 - L2[O] C3 - L1[W] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  0] Utilization = 0.00 | pJ/Compute =   17.843 | L3[WIO] Q1 - L2[WIO] Q1 - L1[] Q1 - L0[] Q56 P56 N4 S11 R11 M96 C3
# [  5] Utilization = 0.00 | pJ/Compute =   42.995 | L3[WIO] C3 - L2[O] Q1 - L1[W] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  4] Utilization = 0.00 | pJ/Compute =   15.237 | L3[WIO] Q1 - L2[IO] C3 - L1[W] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  5] Utilization = 0.00 | pJ/Compute =   15.237 | L3[WIO] C3 - L2[IO] Q1 - L1[W] Q1 - L0[] Q56 P56 N4 S11 R11 M96
# [  2] Utilization = 0.00 | pJ/Compute =   45.601 | L3[WIO] Q1 - L2[WO] Q1 - L1[] C3 - L0[] Q56 P56 N4 S11 R11 M96
# [  2] Utilization = 0.00 | pJ/Compute =   17.843 | L3[WIO] Q1 - L2[WIO] Q1 - L1[] C3 - L0[] Q56 P56 N4 S11 R11 M96
# [  0] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  5] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  4] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 0.01 | pJ/Compute =   11.927
# Processing mobilenet_conv1_sparse with unstructured_sparse_tensor_core...
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using all available hardware threads = 11
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 6
#   Factorization options along problem dimension S = 6
#   Factorization options along problem dimension E = 756
#   Factorization options along problem dimension F = 756
#   Factorization options along problem dimension C = 6
#   Factorization options along problem dimension M = 252
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 31109847552
# Mapspace Dimension [LoopPermutation] Size: 106562062388507443200000
# Mapspace Dimension [Spatial] Size: 81
# Mapspace Dimension [DatatypeBypass] Size: 512
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 2828167960 Residue: 8
# Mapspace construction complete.
# Search configuration complete.
# [  3] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  9] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  0] Utilization = 0.00 | pJ/Compute =  127.262 | L3[WIO] G1 - L2[] G1 - L1[] G1 - L0[] M32 C3 F112 E112 S3 R3
# [  1] Utilization = 0.01 | pJ/Compute =   84.595 | L3[WIO] G1 - L2[] G1 - L1[] G1 R3Y - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =   84.595 | L3[WIO] G1 - L2[] R3 - L1[] G1 S3Y - L0[] M32 C3 F112 E112
# [  5] Utilization = 0.00 | pJ/Compute =  127.262 | L3[WIO] R3 - L2[] G1 - L1[] G1 - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =   84.595 | L3[WIO] G1 - L2[] G1 - L1[] R3 S3Y - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =   70.373 | L3[WIO] G1 - L2[] G1 - L1[] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  6] Utilization = 0.01 | pJ/Compute =   84.595 | L3[WIO] G1 - L2[] G1 - L1[] G1 S3Y - L0[] M32 C3 F112 E112 R3
# [  4] Utilization = 0.00 | pJ/Compute =  127.262 | L3[WIO] G1 - L2[] R3 - L1[] G1 - L0[] M32 C3 F112 E112 S3
# [  2] Utilization = 0.00 | pJ/Compute =  127.262 | L3[WIO] G1 - L2[] G1 - L1[] R3 - L0[] M32 C3 F112 E112 S3
# [  0] Utilization = 0.00 | pJ/Compute =   96.847 | L3[WIO] G1 - L2[] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3 R3
# [ 10] Utilization = 0.01 | pJ/Compute =   54.180 | L3[WIO] G1 - L2[] R3 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =   54.180 | L3[WIO] G1 - L2[] G1 - L1[W] R3 S3Y - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =   39.958 | L3[WIO] G1 - L2[] G1 - L1[W] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  5] Utilization = 0.00 | pJ/Compute =   96.847 | L3[WIO] R3 - L2[] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =   54.180 | L3[WIO] G1 - L2[] G1 - L1[W] G1 R3Y - L0[] M32 C3 F112 E112 S3
# [  2] Utilization = 0.00 | pJ/Compute =   96.847 | L3[WIO] G1 - L2[] G1 - L1[W] R3 - L0[] M32 C3 F112 E112 S3
# [  4] Utilization = 0.00 | pJ/Compute =   96.847 | L3[WIO] G1 - L2[] R3 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  0] Utilization = 0.00 | pJ/Compute =   69.167 | L3[WIO] G1 - L2[I] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3 R3
# [ 10] Utilization = 0.01 | pJ/Compute =   26.500 | L3[WIO] G1 - L2[I] R3 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112
# [  5] Utilization = 0.00 | pJ/Compute =   69.167 | L3[WIO] R3 - L2[I] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =   26.500 | L3[WIO] G1 - L2[I] G1 - L1[W] G1 R3Y - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =   26.500 | L3[WIO] G1 - L2[I] G1 - L1[W] R3 S3Y - L0[] M32 C3 F112 E112
# [  4] Utilization = 0.00 | pJ/Compute =   69.167 | L3[WIO] G1 - L2[I] R3 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  2] Utilization = 0.00 | pJ/Compute =   69.167 | L3[WIO] G1 - L2[I] G1 - L1[W] R3 - L0[] M32 C3 F112 E112 S3
# [  6] Utilization = 0.01 | pJ/Compute =   54.180 | L3[WIO] G1 - L2[] G1 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112 R3
# [  7] Utilization = 0.04 | pJ/Compute =   12.278 | L3[WIO] G1 - L2[I] G1 - L1[W] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  0] Utilization = 0.00 | pJ/Compute =   44.109 | L3[WIO] G1 - L2[O] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3 R3
# [  6] Utilization = 0.01 | pJ/Compute =   26.500 | L3[WIO] G1 - L2[I] G1 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112 R3
# [ 10] Utilization = 0.01 | pJ/Compute =   10.513 | L3[WIO] G1 - L2[IO] R3 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112
# [  0] Utilization = 0.00 | pJ/Compute =   16.429 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3 R3
# [  1] Utilization = 0.01 | pJ/Compute =   10.513 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 R3Y - L0[] M32 C3 F112 E112 S3
# [  2] Utilization = 0.00 | pJ/Compute =   44.109 | L3[WIO] G1 - L2[O] G1 - L1[W] R3 - L0[] M32 C3 F112 E112 S3
# [  2] Utilization = 0.00 | pJ/Compute =   16.429 | L3[WIO] G1 - L2[IO] G1 - L1[W] R3 - L0[] M32 C3 F112 E112 S3
# [  7] Utilization = 0.04 | pJ/Compute =    8.541 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  5] Utilization = 0.00 | pJ/Compute =   44.109 | L3[WIO] R3 - L2[O] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  5] Utilization = 0.00 | pJ/Compute =   16.429 | L3[WIO] R3 - L2[IO] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  4] Utilization = 0.00 | pJ/Compute =   44.109 | L3[WIO] G1 - L2[O] R3 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =   10.513 | L3[WIO] G1 - L2[IO] G1 - L1[W] R3 S3Y - L0[] M32 C3 F112 E112
# [  4] Utilization = 0.00 | pJ/Compute =   16.429 | L3[WIO] G1 - L2[IO] R3 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  6] Utilization = 0.01 | pJ/Compute =   10.513 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112 R3
# [  5] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  4] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [ 10] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  8] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  6] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 0.04 | pJ/Compute =    8.541
# real	0m1.253s
# user	0m2.470s
# sys	0m0.132s

# %%
# %%bash
# cd /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts && \
# chmod +x parse_and_plot1.py && \
# time ./parse_and_plot1.py
# Out:
# Summary Statistics:
#
# Unstructured Sparse Architecture:
# resnet50_conv1:
#   Cycles: 1,404,928
#   Energy: 52,738,074.87 pJ
#   Utilization: 84.00%
# alexnet_conv1_sparse:
#   Cycles: 145,711,104
#   Energy: 195,346,134.47 pJ
#   Utilization: 3.00%
# mobilenet_conv1_sparse:
#   Cycles: 1,204,224
#   Energy: 4,843,292.59 pJ
#   Utilization: 9.00%
# Unstructured sparse architecture plots created successfully!
# real	0m1.170s
# user	0m2.752s
# sys	0m3.728s

# %%
from IPython.display import Image
import matplotlib.pyplot as plt

# Define path to the figure using the absolute path
unstructured_comparison_fig = "../evaluation_setups/unstructured_sparse_eval/outputs/figures/unstructured_comparison.png"
# Display the image directly using IPython's Image display
Image(filename=unstructured_comparison_fig)

# %%
# %%bash
# cd /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts
# echo "Running evaluation sweep for unstructured spares architecture with no overhead"
# chmod +x sweep2.sh
# time ./sweep2.sh
# Out:
# Running evaluation sweep for unstructured spares architecture with no overhead
# + WORKLOADS=("resnet50_conv1" "alexnet_conv1_sparse" "mobilenet_conv1_sparse")
# +++ dirname ./sweep2.sh
# ++ cd .
# ++ pwd
# + SCRIPT_DIR=/home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts
# ++ dirname /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts
# + BASE_DIR=/home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval
# + echo 'Script directory: /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts'
# Script directory: /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts
# Base directory: /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval
# + echo 'Base directory: /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval'
# ++ pwd
# + echo 'Current directory: /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts'
# Current directory: /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts
# Contents of script directory:
# + echo 'Contents of script directory:'
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts
# total 24
# drwxr-xr-x  8 workspace workspace  256 Apr  4 05:42 .
# drwxr-xr-x 10 workspace workspace  320 Apr  4 04:37 ..
# -rwxr-xr-x  1 workspace workspace 4067 Apr  4 05:22 parse_and_plot1.py
# -rwxr-xr-x  1 workspace workspace 3874 Apr  4 05:28 parse_and_plot2.py
# -rwxr-xr-x  1 workspace workspace  986 Apr  4 04:57 sweep1.sh
# -rwxr-xr-x  1 workspace workspace 1739 Apr  4 05:58 sweep2.sh
# -rw-r--r--  1 workspace workspace 1503 Apr  4 04:36 timeloop-mapper.accelergy.log
# -rw-r--r--  1 workspace workspace 2593 Apr  4 04:36 timeloop-model.accelergy.log
# + echo 'Contents of base directory:'
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval
# Contents of base directory:
# total 0
# drwxr-xr-x 10 workspace workspace 320 Apr  4 04:37 .
# drwxr-xr-x  9 workspace workspace 288 Apr  4 04:33 ..
# drwxr-xr-x  4 workspace workspace 128 Apr  4 04:52 arch
# drwxr-xr-x  3 workspace workspace  96 Apr  4 04:33 dataflow
# drwxr-xr-x  8 workspace workspace 256 Apr  4 05:56 ert_art
# drwxr-xr-x  3 workspace workspace  96 Apr  4 04:34 mapper
# drwxr-xr-x 21 workspace workspace 672 Apr  4 04:59 outputs
# drwxr-xr-x  8 workspace workspace 256 Apr  4 05:42 scripts
# drwxr-xr-x  4 workspace workspace 128 Apr  4 04:56 sparse-opt
# drwxr-xr-x  5 workspace workspace 160 Apr  4 04:34 workload
# + which timeloop-mapper
# /usr/local/bin/timeloop-mapper
# + timeloop-mapper --version
# ERROR: Input configuration file does not end with .cfg, .yml, or .yaml
# + for workload in "${WORKLOADS[@]}"
# + echo 'Processing resnet50_conv1 with ideal_sparse_tensor_core...'
# + mkdir -p /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/outputs/ideal_resnet50_conv1
# Processing resnet50_conv1 with ideal_sparse_tensor_core...
# + echo 'Checking required files:'
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/arch/ideal_sparse_tensor_core.yaml
# Checking required files:
# -rw-r--r-- 1 workspace workspace 3224 Apr  4 05:53 /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/arch/ideal_sparse_tensor_core.yaml
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/dataflow/weight_stationary.yaml
# -rw-r--r-- 1 workspace workspace 425 Apr  4 05:49 /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/dataflow/weight_stationary.yaml
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/sparse-opt/ideal.yaml
# -rw-r--r-- 1 workspace workspace 251 Apr  4 05:51 /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/sparse-opt/ideal.yaml
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/workload/resnet50_conv1.yaml
# -rw-r--r-- 1 workspace workspace 961 Apr  4 04:34 /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/workload/resnet50_conv1.yaml
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/mapper/mapper.yaml
# -rw-r--r-- 1 workspace workspace 357 Apr  4 04:34 /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/mapper/mapper.yaml
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/ert_art/ERT_ideal.yaml
# -rw-r--r-- 1 workspace workspace 1580 Apr  4 05:56 /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/ert_art/ERT_ideal.yaml
# + ls -la /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/ert_art/ART.yaml
# -rw-r--r-- 1 workspace workspace 312 Apr  4 04:34 /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/ert_art/ART.yaml
# + timeloop-mapper /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/arch/ideal_sparse_tensor_core.yaml /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/dataflow/weight_stationary.yaml /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/sparse-opt/ideal.yaml /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/workload/resnet50_conv1.yaml /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/mapper/mapper.yaml /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/ert_art/ERT_ideal.yaml /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/ert_art/ART.yaml -o /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/outputs/ideal_resnet50_conv1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using all available hardware threads = 11
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 6
#   Factorization options along problem dimension M = 462
#   Factorization options along problem dimension R = 6
#   Factorization options along problem dimension S = 6
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 756
#   Factorization options along problem dimension Q = 756
# Mapspace Dimension [IndexFactorization] Size: 57034720512
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 64
# Mapspace Dimension [DatatypeBypass] Size: 512
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 5184974592 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  7] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  9] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.20 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.20 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [ 10] Utilization = 0.20 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[W] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[W] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[I] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[I] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[WI] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[WI] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[O] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[O] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[WO] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[WO] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[IO] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[IO] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] Q1 - L1[] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[WIO] Q1 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] Q1 - L1[W] Q1 C3Y - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] C3 - L2[WIO] Q1 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] Q1 - L1[] C3 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] C3 - L1[] Q1 - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] Q1 - L1[W] C3 - L0[] Q112 P112 S7 R7 M64
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] C3 - L1[W] Q1 - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] Q1 - L1[] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[] Q1 - L1[W] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] Q1 - L1[] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[W] Q1 - L1[W] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] Q1 - L1[] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[I] Q1 - L1[W] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] Q1 - L1[] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WI] Q1 - L1[W] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  6] Utilization = 0.20 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] Q1 - L1[] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[O] Q1 - L1[W] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] Q1 - L1[] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WO] Q1 - L1[W] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[W] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] Q1 - L1[] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[W] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 C3 M2Y - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[IO] Q1 - L1[W] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] Q1 - L1[] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[I] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] Q1 - L2[WIO] Q1 - L1[W] Q1 C3X - L0[] Q112 P112 S7 R7 M64
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[I] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[WI] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[WI] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  8] Utilization = 0.20 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7 C3
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[O] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[O] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[WO] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[WO] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 M2Y - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[IO] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[IO] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[WIO] P2 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [ 10] Utilization = 0.20 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[WIO] P2 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2X - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 C3 M2X - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.19 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.33 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.33 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2X - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.33 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[W] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  6] Utilization = 0.20 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2Y - L1[W] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  1] Utilization = 0.24 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 C3 M2X - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2Y - L1[W] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.33 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [  1] Utilization = 0.26 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2Y - L1[W] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  1] Utilization = 0.33 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[W] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2Y - L1[W] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 C3 M2Y - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2X - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  4] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WIO] P2 C3 M2Y - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 M2X - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2X - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2X - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [  0] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 M2X - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2 C3
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[I] P2 C3 M2X - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2X - L1[] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[] P2 M2X - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2X - L1[] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[] P2 M2X - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2X - L1[W] Q14 M4 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[W] P2 M2X - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [ 10] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WI] P2 C3 M2X - L1[W] Q14 M4 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[W] P2 M2X - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[I] P2 M2X - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[I] P2 M2X - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2X - L1[W] Q14 M4 C3 R7Y M4X - L0[W] Q8 P56 S7
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[WI] P2 M2X - L1[] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  5] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 C3 - L2[WI] P2 M2X - L1[W] Q14 M4 R7Y M2X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[] P2 M2X - L1[W] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  8] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[IO] P2 M2X - L1[] Q14 M4 C3 R7Y M4X - L0[] Q8 P56 S7
# [  1] Utilization = 0.20 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  1] Utilization = 0.33 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  2] Utilization = 0.11 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[W] P2 M2X - L1[] Q14 M4 C3 R7Y M2X - L0[] Q8 P56 S7 M2
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# [  1] Utilization = 0.32 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[WO] P2 M2Y - L1[] Q14 M4 R7Y M2X C3X - L0[] Q8 P56 S7 M2
# [  6] Utilization = 0.22 | pJ/Compute =    0.000 | L3[WIO] M2 - L2[O] P2 M2Y - L1[W] Q14 M4 M4Y R7X - L0[] Q8 P56 S7 C3
# ...
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] R3 - L2[WO] G1 - L1[] G1 - L0[] M32 C3 F112 E112 S3
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] R3 - L2[WO] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  0] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112 R3
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[] R3 - L0[] M32 C3 F112 E112 S3
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] R3 - L1[] G1 - L0[] M32 C3 F112 E112 S3
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] R3 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] R3 - L2[IO] G1 - L1[] G1 - L0[] M32 C3 F112 E112 S3
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] R3 - L1[] G1 - L0[] M32 C3 F112 E112 S3
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] R3 - L2[IO] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] R3 - L1[] G1 S3Y - L0[] M32 C3 F112 E112
# [  4] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] R3 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[W] R3 - L0[] M32 C3 F112 E112 S3
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] R3 - L2[WIO] G1 - L1[] G1 - L0[] M32 C3 F112 E112 S3
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[] R3 - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[] G1 R3Y - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] R3 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[W] R3 - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[] R3 S3Y - L0[] M32 C3 F112 E112
# [  5] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] R3 - L2[WIO] G1 - L1[W] G1 - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 R3Y - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] R3 - L1[] G1 S3Y - L0[] M32 C3 F112 E112
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[] R3 - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[W] R3 S3Y - L0[] M32 C3 F112 E112
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[W] R3 - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[] G1 R3Y - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] R3 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[] R3 - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[] R3 S3Y - L0[] M32 C3 F112 E112
# [  2] Utilization = 0.00 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] R3 - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] G1 R3Y - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] R3 - L1[] G1 S3Y - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[W] R3 S3Y - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] R3 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[W] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] R3 - L1[] G1 S3Y - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] R3 - L1[W] G1 S3Y - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[W] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[] R3 S3Y - L0[] M32 C3 F112 E112
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] G1 - L1[] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] G1 - L1[W] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] G1 - L1[] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[W] R3 S3Y - L0[] M32 C3 F112 E112
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] G1 - L1[W] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[] R3 S3Y - L0[] M32 C3 F112 E112
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] G1 - L1[] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] G1 - L1[W] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] G1 - L1[] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] G1 - L1[] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] R3 S3Y - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] G1 - L1[W] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] G1 - L1[] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] G1 - L1[W] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] G1 - L1[W] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] G1 S3Y R3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] G1 - L1[] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] G1 - L1[W] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] G1 - L1[] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] G1 - L1[W] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[W] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[W] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  6] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] G1 S3X - L0[] M32 C3 F112 E112 R3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[W] G1 R3X - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] R3 - L1[] G1 S3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[] G1 R3X - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] R3 - L1[W] G1 S3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[W] G1 R3X - L0[] M32 C3 F112 E112 S3
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] R3 - L1[] G1 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] R3 - L1[W] G1 S3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] G1 - L1[] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] G1 - L1[] R3 S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] G1 - L1[W] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[] G1 - L1[W] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] G1 - L1[] R3 S3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] G1 - L1[W] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] G1 - L1[] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] R3 - L1[] G1 S3X - L0[] M32 C3 F112 E112
# [  1] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] G1 R3X - L0[] M32 C3 F112 E112 S3
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] G1 - L1[] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[W] G1 - L1[W] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] R3 - L1[W] G1 S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] G1 - L1[W] R3 S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] G1 - L1[] R3 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] R3 - L1[] G1 S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] G1 - L1[W] R3 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] R3 - L1[W] G1 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] G1 - L1[] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[I] G1 - L1[W] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] G1 - L1[] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WI] G1 - L1[W] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] R3 - L1[] G1 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] R3 - L1[W] G1 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] R3 - L1[] G1 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] R3 - L1[W] G1 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] R3 - L1[] G1 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] R3 - L1[W] G1 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] R3 - L1[] G1 S3X - L0[] M32 C3 F112 E112
# [ 10] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] R3 - L1[W] G1 S3X - L0[] M32 C3 F112 E112
# [  0] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[] R3 S3X - L0[] M32 C3 F112 E112
# [  4] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  5] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[W] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[O] G1 - L1[W] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[W] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WO] G1 - L1[W] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  6] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[] R3 S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[W] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[IO] G1 - L1[W] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  8] Utilization = 0.01 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] R3 S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  7] Utilization = 0.04 | pJ/Compute =    0.000 | L3[WIO] G1 - L2[WIO] G1 - L1[W] G1 R3Y S3X - L0[] M32 C3 F112 E112
# [  2] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [ 10] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  8] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 3600 invalid mappings (3600 fanout, 0 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 0.01 | pJ/Compute =    0.000
# real	0m1.823s
# user	0m3.028s
# sys	0m0.213s

# %%
# %%bash
# cd /home/workspace/2022.micro.artifact/evaluation_setups/unstructured_sparse_eval/scripts && \
# chmod +x parse_and_plot2.py && \
# time ./parse_and_plot2.py
# Out:
# Summary Statistics:
#
# Ideal Sparse Architecture:
# resnet50_conv1:
#   Cycles: 2,107,392
#   Energy: 0.0 pJ
#   Utilization: 56.00%
# alexnet_conv1_sparse:
#   Cycles: 437,133,312
#   Energy: 0.0 pJ
#   Utilization: 1.00%
# mobilenet_conv1_sparse:
#   Cycles: 3,612,672
#   Energy: 0.0 pJ
#   Utilization: 3.00%
# Ideal sparse architecture plots created successfully!
# real	0m1.146s
# user	0m2.791s
# sys	0m3.675s

# %%
from IPython.display import Image
import matplotlib.pyplot as plt

# Define path to the figure using the relative path
ideal_comparison_fig = "../evaluation_setups/unstructured_sparse_eval/outputs/figures/ideal_comparison.png"

# Display the image directly using IPython's Image display
Image(filename=ideal_comparison_fig)

# %%
# Step 4: Detailed Analysis of Results
import pandas as pd
import numpy as np
import sys
import os
import re
import matplotlib.pyplot as plt

# Function to parse stats directly from the text file
def parse_stats_file(stats_file):
    if not os.path.exists(stats_file):
        return None
    
    stats = {}
    try:
        with open(stats_file, 'r') as f:
            content = f.read()
            
            # Extract cycles
            cycles_match = re.search(r'Cycles\s+:\s+(\d+)', content)
            if cycles_match:
                stats['cycles'] = int(cycles_match.group(1))
            
            # Extract total energy
            energy_match = re.search(r'Energy \(total\)\s+:\s+([\d.]+)', content)
            if energy_match:
                stats['energy'] = float(energy_match.group(1))
            
            # Extract utilization
            util_match = re.search(r'Utilized instances \(average\)\s+:\s+([\d.]+)', content)
            if util_match:
                stats['utilization'] = float(util_match.group(1))
                
            # Extract per-level energy
            level_pattern = r'Level (\d+)\n-------\n=== ([^\n]+) ===.*?Energy \(total\)\s+:\s+([\d.]+) pJ'
            level_matches = re.finditer(level_pattern, content, re.DOTALL)
            
            level_energy = {}
            for match in level_matches:
                level_num = int(match.group(1))
                level_name = match.group(2)
                level_energy_val = float(match.group(3))
                level_energy[f"Level{level_num}_{level_name}"] = level_energy_val
            
            stats['level_energy'] = level_energy
                
        return stats
    except Exception as e:
        print(f"Error parsing {stats_file}: {e}")
        return None

# Load and process the results for both architectures
workloads = ["resnet50_conv1", "alexnet_conv1_sparse", "mobilenet_conv1_sparse"]
workload_display_names = {'resnet50_conv1': 'ResNet-50', 
                          'alexnet_conv1_sparse': 'AlexNet', 
                          'mobilenet_conv1_sparse': 'MobileNet'}

unstructured_results = {}
ideal_results = {}

for workload in workloads:
    # Unstructured sparse architecture results
    unstructured_stats_file = f"../evaluation_setups/unstructured_sparse_eval/outputs/unstructured_{workload}/timeloop-mapper.stats.txt"
    stats = parse_stats_file(unstructured_stats_file)
    if stats:
        unstructured_results[workload] = stats
    
    # Ideal sparse architecture results
    ideal_stats_file = f"../evaluation_setups/unstructured_sparse_eval/outputs/ideal_{workload}/timeloop-mapper.stats.txt"
    stats = parse_stats_file(ideal_stats_file)
    if stats:
        ideal_results[workload] = stats

# Create DataFrames for comparison
def create_dataframe(results, workloads):
    data = []
    for workload in workloads:
        if workload in results:
            row = {
                'Workload': workload_display_names[workload],
                'Cycles': results[workload].get('cycles', 0),
                'Energy (pJ)': results[workload].get('energy', 0),
                'Utilization (%)': results[workload].get('utilization', 0) * 100  # Convert to percentage
            }
            data.append(row)
    return pd.DataFrame(data)

unstructured_df = create_dataframe(unstructured_results, workloads)
ideal_df = create_dataframe(ideal_results, workloads)

# Calculate improvement ratios
if not unstructured_df.empty and not ideal_df.empty:
    # Make sure both dataframes have the same workloads
    common_workloads = set(unstructured_df['Workload']).intersection(set(ideal_df['Workload']))
    unstructured_filtered = unstructured_df[unstructured_df['Workload'].isin(common_workloads)]
    ideal_filtered = ideal_df[ideal_df['Workload'].isin(common_workloads)]
    
    # Sort both DataFrames by workload to ensure they match
    unstructured_filtered = unstructured_filtered.sort_values('Workload').reset_index(drop=True)
    ideal_filtered = ideal_filtered.sort_values('Workload').reset_index(drop=True)
    
    comparison_df = pd.DataFrame({
        'Workload': unstructured_filtered['Workload'],
        'Cycle Ratio (Unstructured/Ideal)': unstructured_filtered['Cycles'] / ideal_filtered['Cycles'].replace(0, np.nan),
        'Energy Ratio (Unstructured/Ideal)': unstructured_filtered['Energy (pJ)'] / ideal_filtered['Energy (pJ)'].replace(0, np.nan),
        'Utilization Ratio (Ideal/Unstructured)': ideal_filtered['Utilization (%)'] / unstructured_filtered['Utilization (%)'].replace(0, np.nan)
    })
else:
    comparison_df = pd.DataFrame(columns=['Workload', 'Cycle Ratio (Unstructured/Ideal)', 
                                          'Energy Ratio (Unstructured/Ideal)', 'Utilization Ratio (Ideal/Unstructured)'])

# Energy breakdown by hardware level
print("Energy Breakdown by Hardware Level:")
print("=" * 60)

for arch_name, results in [('Unstructured', unstructured_results), ('Ideal', ideal_results)]:
    print(f"\n{arch_name} Architecture:")
    
    for workload in workloads:
        if workload in results and 'level_energy' in results[workload]:
            level_energy = results[workload]['level_energy']
            total_energy = results[workload].get('energy', 0)
            
            if level_energy and total_energy > 0:
                print(f"\n{workload_display_names[workload]}:")
                
                for level, energy in level_energy.items():
                    percentage = (energy / total_energy) * 100
                    print(f"  {level}: {energy:,.2f} pJ ({percentage:.2f}%)")
            else:
                print(f"\n{workload_display_names[workload]}: Energy breakdown not available")

# Display the summary analysis
print("\nPerformance Comparison: Unstructured vs Ideal")
print("=" * 60)
print("Unstructured Sparse Architecture:")
if not unstructured_df.empty:
    print(unstructured_df.to_string(index=False))
else:
    print("No data available")

print("\nIdeal Sparse Architecture:")
if not ideal_df.empty:
    print(ideal_df.to_string(index=False))
else:
    print("No data available")

print("\nImprovement Ratios:")
if not comparison_df.empty:
    print(comparison_df.to_string(index=False))
else:
    print("No data available for comparison")

print("\nKey Observations:")
print("-" * 60)

if not comparison_df.empty:
    # Filter out NaN and infinity values
    cycle_ratios = comparison_df['Cycle Ratio (Unstructured/Ideal)'].replace([np.inf, -np.inf], np.nan).dropna()
    energy_ratios = comparison_df['Energy Ratio (Unstructured/Ideal)'].replace([np.inf, -np.inf], np.nan).dropna()
    
    if not cycle_ratios.empty:
        avg_cycle_ratio = cycle_ratios.mean()
        print(f"1. Average cycle overhead from sparse metadata: {avg_cycle_ratio:.2f}x")
    else:
        print("1. Cannot calculate average cycle overhead (insufficient data)")
    
    if not energy_ratios.empty:
        avg_energy_ratio = energy_ratios.mean()
        print(f"2. Average energy overhead from sparse metadata: {avg_energy_ratio:.2f}x")
    else:
        print("2. Cannot calculate average energy overhead (insufficient data)")
    
    print("\n3. Workload-Specific Impact:")
    for _, row in comparison_df.iterrows():
        cycle_ratio = row['Cycle Ratio (Unstructured/Ideal)']
        energy_ratio = row['Energy Ratio (Unstructured/Ideal)']
        
        result_str = f"   - {row['Workload']}: "
        if not pd.isna(cycle_ratio) and not np.isinf(cycle_ratio):
            result_str += f"{cycle_ratio:.2f}x cycle overhead, "
        else:
            result_str += "cycle data unavailable, "
            
        if not pd.isna(energy_ratio) and not np.isinf(energy_ratio):
            result_str += f"{energy_ratio:.2f}x energy overhead"
        else:
            result_str += "energy data unavailable"
            
        print(result_str)
else:
    print("Not enough data available for meaningful observations")

print("\n4. Recommendations for Hardware Optimization:")
print("   - Optimize hardware for sparse metadata handling to reduce cycle and energy overhead")
print("   - Focus optimizations on memory levels with highest energy consumption")
print("   - Consider workload-specific accelerator configurations based on observed patterns")
# Out:
# Energy Breakdown by Hardware Level:
# ============================================================
#
# Unstructured Architecture:
#
# ResNet-50:
#   Level0_MAC: 52,738,074.87 pJ (100.00%)
#   Level1_LRF: 186,754,438.36 pJ (354.12%)
#   Level3_SMEM: 124,295,153.70 pJ (235.68%)
#   Level4_DRAM: 301,056.00 pJ (0.57%)
#
# AlexNet:
#   Level0_MAC: 195,346,134.47 pJ (100.00%)
#   Level1_LRF: 1,830,830,416.99 pJ (937.22%)
#   Level4_DRAM: 1,115,136.00 pJ (0.57%)
#
# MobileNet:
#   Level0_MAC: 4,843,292.59 pJ (100.00%)
#   Level1_LRF: 17,150,917.81 pJ (354.12%)
#   Level3_SMEM: 45,571,370.66 pJ (940.92%)
#   Level4_DRAM: 27,648.00 pJ (0.57%)
#
# Ideal Architecture:
#
# ResNet-50: Energy breakdown not available
#
# AlexNet: Energy breakdown not available
#
# MobileNet: Energy breakdown not available
#
# Performance Comparison: Unstructured vs Ideal
# ============================================================
# Unstructured Sparse Architecture:
#  Workload    Cycles  Energy (pJ)  Utilization (%)
# ResNet-50   1404928  52738074.87           8400.0
#   AlexNet 145711104 195346134.47            300.0
# MobileNet   1204224   4843292.59            900.0
#
# Ideal Sparse Architecture:
#  Workload    Cycles  Energy (pJ)  Utilization (%)
# ResNet-50   2107392          0.0           5600.0
#   AlexNet 437133312          0.0            100.0
# MobileNet   3612672          0.0            300.0
#
# Improvement Ratios:
#  Workload  Cycle Ratio (Unstructured/Ideal)  Energy Ratio (Unstructured/Ideal)  Utilization Ratio (Ideal/Unstructured)
#   AlexNet                          0.333333                                NaN                                0.333333
# MobileNet                          0.333333                                NaN                                0.333333
# ResNet-50                          0.666667                                NaN                                0.666667
#
# Key Observations:
# ------------------------------------------------------------
# 1. Average cycle overhead from sparse metadata: 0.44x
# 2. Cannot calculate average energy overhead (insufficient data)
#
# 3. Workload-Specific Impact:
#    - AlexNet: 0.33x cycle overhead, energy data unavailable
#    - MobileNet: 0.33x cycle overhead, energy data unavailable
#    - ResNet-50: 0.67x cycle overhead, energy data unavailable
#
# 4. Recommendations for Hardware Optimization:
#    - Optimize hardware for sparse metadata handling to reduce cycle and energy overhead
#    - Focus optimizations on memory levels with highest energy consumption
#    - Consider workload-specific accelerator configurations based on observed patterns
